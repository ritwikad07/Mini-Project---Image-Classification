# %% [markdown]
# <a href="https://colab.research.google.com/github/ritwikad07/Mini-Project---Image-Classification/blob/master/Image_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
cd /content/drive/My Drive/Data Science
# Out:
# /content/drive/My Drive/Data Science

# %%
# !ls
# Out:
# cat  images

# %%
# !mkdir pic

# %%
cd pictures
# Out:
# /content/drive/My Drive/Data Science/images/pictures

# %%
from bing_image_downloader import downloader
downloader.download("cat", limit=3, output_dir='pictures')
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/d/dc/Grumpy_Cat_%2814556024763%29_%28cropped%29.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.ytimg.com/vi/OAUtiqYDhEc/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://upload.wikimedia.org/wikipedia/commons/4/4d/Cat_November_2010-1a.jpg
# [%] File Downloaded !

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/cat/Image_1.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/cat/Image_2.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/cat/Image_3.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
from bing_image_downloader import downloader
downloader.download("dog", limit=3, output_dir='pictures')
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/b/b4/Dealer_the_Labrador_Retriever_and_a_redhead_duck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Pastor_vasco_m_14months_loby_3018.jpg/1200px-Pastor_vasco_m_14months_loby_3018.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://upload.wikimedia.org/wikipedia/en/thumb/9/97/Chaser_the_BC%2C_snow_full_body.jpg/1200px-Chaser_the_BC%2C_snow_full_body.jpg
# [Error]Invalid image, not saving https://upload.wikimedia.org/wikipedia/en/thumb/9/97/Chaser_the_BC%2C_snow_full_body.jpg/1200px-Chaser_the_BC%2C_snow_full_body.jpg
#
# [!] Issue getting: https://upload.wikimedia.org/wikipedia/en/thumb/9/97/Chaser_the_BC%2C_snow_full_body.jpg/1200px-Chaser_the_BC%2C_snow_full_body.jpg
# [!] Error:: No active exception to reraise
#
#
# [!!]Indexing page: 2
#
# ...

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/dog/Image_1.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/dog/Image_2.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/dog/Image_3.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
from bing_image_downloader import downloader
downloader.download("panda", limit=3, output_dir='pictures')
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.ytimg.com/vi/pVfiFCE9_Cc/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.ytimg.com/vi/tS4Un2l_Wy8/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.thestar.com/content/dam/thestar/news/gta/2016/03/07/baby-pandas-to-make-first-public-appearance-today/jia-panpan-and-jia-yueyue.jpg
# [%] File Downloaded !

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/panda/Image_1.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/panda/Image_2.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/panda/Image_3.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
from bing_image_downloader import downloader
downloader.download("polar bear", limit=3, output_dir='pictures')
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.ytimg.com/vi/-Kfl3385O44/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.ytimg.com/vi/CbILj_CYqno/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.ytimg.com/vi/jMY0zHWSpXI/maxresdefault.jpg
# [%] File Downloaded !

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/polar bear/Image_1.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/polar bear/Image_2.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/polar bear/Image_3.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
from bing_image_downloader import downloader
downloader.download("leopard", limit=3, output_dir='pictures')
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/6/65/I_See_You.jpg/1200px-I_See_You.jpg
# [Error]Invalid image, not saving https://upload.wikimedia.org/wikipedia/commons/thumb/6/65/I_See_You.jpg/1200px-I_See_You.jpg
#
# [!] Issue getting: https://upload.wikimedia.org/wikipedia/commons/thumb/6/65/I_See_You.jpg/1200px-I_See_You.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Persian_Leopard_sitting.jpg/1920px-Persian_Leopard_sitting.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.ytimg.com/vi/Q0zdwQaXHHU/maxresdefault.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ...
#
# [%] Downloading Image #3 from https://upload.wikimedia.org/wikipedia/commons/c/c5/Leopard_africa.jpg
# [%] File Downloaded !
#
#
#
# ...

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/leopard/Image_1.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/leopard/Image_2.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
path="/content/drive/My Drive/Data Science/images/pictures/pictures/leopard/Image_3.jpg"
import cv2
import matplotlib.pyplot as plt

i=cv2.imread(path)
i=cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
import os
import cv2
path= "/content/images/cat"
for filename in os.listdir(path):
  i=cv2.imread(os.path.join(path,filename))
  print(i.shape)
# Out:
# (2397, 1795, 3)
# (1600, 1200, 3)
# (720, 1280, 3)

# %%
import os
from skimage.io import imread
from skimage.transform import resize

# %%
target=[]
flat_data=[]
images=[]

path='/content/images/'
for dirpath, dirnames, filenames in os.walk(path):
  for filename in filenames:
    category = dirpath.split('/')[-1]
    target.append(category)
    img = imread(f'{path}{category}/{filename}')
    img_resized=resize(img,(50,50))
    flat_data.append(img_resized.flatten())
    images.append(img_resized)

import numpy as np
flat_data=np.array(flat_data)
target=np.array(target)
images=np.array(images)

print(flat_data.shape)
print(target.shape)
print(images.shape)
# Out:
# (18, 7500)
# (18,)
# (18, 50, 50, 3)

# %%
import pandas as pd
df=pd.DataFrame(flat_data)
df['Target']=target

# %%
df.head()
# Out:
#           0         1         2  ...      7498      7499   Target
# 0  0.658824  0.698039  0.762549  ...  0.925490  0.905882      cat
# 1  0.913725  0.654902  0.352941  ...  0.015686  0.007843      cat
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000      cat
# 3  0.690196  0.713725  0.737255  ...  0.650980  0.394118  leopard
# 4  0.156863  0.164784  0.200157  ...  0.474510  0.474510  leopard
#
# [5 rows x 7501 columns]
